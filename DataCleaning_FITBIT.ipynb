# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import datetime as dt
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing Data files

# %%
daily_activity= pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/dailyActivity_merged.csv')
hourly_calories=pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/hourlyCalories_merged.csv')
hourly_steps=pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/hourlySteps_merged.csv')
sleep_day=pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/sleepDay_merged.csv')
weight_log=pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/weightLogInfo_merged.csv')
heartrate_seconds=pd.read_csv('/content/drive/MyDrive/PrepInsta/Week 8/1. Raw Data/heartrate_seconds_merged.csv')

# %% [markdown]
# Daily Activity

# %%
daily_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
daily_activity.tail()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
# ...

# %%
daily_activity.shape
# Out:
# (940, 15)

# %%
daily_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# We have no null values

# %%
daily_activity['Id'].nunique()
# Out:
# 33

# %% [markdown]
# Data of 33 User in present in the dataset.

# %%
daily_activity.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
daily_activity['ActivityDate'] = pd.to_datetime(daily_activity['ActivityDate'])

# %%
daily_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    datetime64[ns]
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %% [markdown]
# Data has been cleaned and proper EDA is done, all the fields have proper data types with no null Values.

# %%
daily_activity.to_csv('DailyActivity.csv', index=False)

# %% [markdown]
# Sleep Day

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_day.tail()
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# 408             360
# 409             527
# 410             423
# 411             545
# 412             463

# %%
sleep_day.shape
# Out:
# (413, 5)

# %%
sleep_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    object
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 16.3+ KB

# %%
sleep_day['Id'].nunique()
# Out:
# 24

# %% [markdown]
# Data of 24 User in present in the dataset.

# %%
sleep_day.describe()
# Out:
#                  Id  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# count  4.130000e+02         413.000000          413.000000      413.000000
# mean   5.000979e+09           1.118644          419.467312      458.639225
# std    2.060360e+09           0.345521          118.344679      127.101607
# min    1.503960e+09           1.000000           58.000000       61.000000
# 25%    3.977334e+09           1.000000          361.000000      403.000000
# 50%    4.702922e+09           1.000000          433.000000      463.000000
# 75%    6.962181e+09           1.000000          490.000000      526.000000
# max    8.792010e+09           3.000000          796.000000      961.000000

# %%
sleep_day['SleepDay'] = pd.to_datetime(sleep_day['SleepDay'])
# Out:
# <ipython-input-25-c6f0396ecfe8>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sleep_day['SleepDay'] = pd.to_datetime(sleep_day['SleepDay'])

# %%
sleep_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  413 non-null    int64
#  1   SleepDay            413 non-null    datetime64[ns]
#  2   TotalSleepRecords   413 non-null    int64
#  3   TotalMinutesAsleep  413 non-null    int64
#  4   TotalTimeInBed      413 non-null    int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 16.3 KB

# %% [markdown]
# Data has been cleaned and proper EDA is done, all the fields have proper data types with no null Values.

# %%
sleep_day.to_csv('SleepDay.csv', index=False)

# %% [markdown]
# Weight Log

# %%
weight_log.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
weight_log.tail()
# Out:
#             Id                  Date   WeightKg  WeightPounds  Fat        BMI  \
# 62  8877689391   5/6/2016 6:43:35 AM  85.000000    187.392923  NaN  25.440001
# 63  8877689391   5/8/2016 7:35:53 AM  85.400002    188.274775  NaN  25.559999
# 64  8877689391   5/9/2016 6:39:44 AM  85.500000    188.495234  NaN  25.610001
# 65  8877689391  5/11/2016 6:51:47 AM  85.400002    188.274775  NaN  25.559999
# 66  8877689391  5/12/2016 6:42:53 AM  84.000000    185.188300  NaN  25.139999
#
#     IsManualReport          LogId
# 62           False  1462517015000
# 63           False  1462692953000
# 64           False  1462775984000
# 65           False  1462949507000
# 66           False  1463035373000

# %%
weight_log.shape
# Out:
# (67, 8)

# %%
weight_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
weight_log['Id'].nunique()
# Out:
# 8

# %% [markdown]
# Data of 8 User in present in the dataset.

# %%
weight_log.describe()
# Out:
#                  Id    WeightKg  WeightPounds       Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000   2.00000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.50000  25.185224
# std    1.950322e+09   13.923206     30.695415   2.12132   3.066963
# min    1.503960e+09   52.599998    115.963147  22.00000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  22.75000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.50000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  24.25000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.00000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461772e+12
# std    7.829948e+08
# min    1.460444e+12
# 25%    1.461079e+12
# 50%    1.461802e+12
# 75%    1.462375e+12
# max    1.463098e+12

# %%
weight_log['Date'] = pd.to_datetime(weight_log['Date'])
# Out:
# <ipython-input-36-2294e49f5ad5>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weight_log['Date'] = pd.to_datetime(weight_log['Date'])

# %%
weight_log.drop(columns=['Fat'], inplace=True)

# %%
weight_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     datetime64[ns]
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   BMI             67 non-null     float64
#  5   IsManualReport  67 non-null     bool
#  6   LogId           67 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(2)
# memory usage: 3.3 KB

# %% [markdown]
# Data has been cleaned and proper EDA is done, all the fields have proper data types with no null Values.

# %%
weight_log.to_csv('WeightLog.csv', index=False)

# %% [markdown]
# Heartrate Seconds

# %%
heartrate_seconds.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
heartrate_seconds.tail()
# Out:
#                  Id                  Time  Value
# 2483653  8877689391  5/12/2016 2:43:53 PM     57
# 2483654  8877689391  5/12/2016 2:43:58 PM     56
# 2483655  8877689391  5/12/2016 2:44:03 PM     55
# 2483656  8877689391  5/12/2016 2:44:18 PM     55
# 2483657  8877689391  5/12/2016 2:44:28 PM     56

# %%
heartrate_seconds.shape
# Out:
# (2483658, 3)

# %%
heartrate_seconds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
heartrate_seconds['Id'].nunique()
# Out:
# 14

# %% [markdown]
# Data of 14 User in present in the dataset.

# %%
heartrate_seconds.describe()
# Out:
#                  Id         Value
# count  2.483658e+06  2.483658e+06
# mean   5.513765e+09  7.732842e+01
# std    1.950224e+09  1.940450e+01
# min    2.022484e+09  3.600000e+01
# 25%    4.388162e+09  6.300000e+01
# 50%    5.553957e+09  7.300000e+01
# 75%    6.962181e+09  8.800000e+01
# max    8.877689e+09  2.030000e+02

# %%
heartrate_seconds['Time'] = pd.to_datetime(heartrate_seconds['Time'])

# %%
heartrate_seconds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    datetime64[ns]
#  2   Value   int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 56.8 MB

# %% [markdown]
# Data has been cleaned and proper EDA is done, all the fields have proper data types with no null Values.

# %%
heartrate_seconds.to_csv('HeartrateSeconds.csv', index=False)

# %% [markdown]
# Hourly Calories and Steps

# %%
hourly_calories.columns
# Out:
# Index(['Id', 'ActivityHour', 'Calories'], dtype='object')

# %%
hourly_steps.columns
# Out:
# Index(['Id', 'ActivityHour', 'StepTotal'], dtype='object')

# %%
print(hourly_calories.shape)
print(hourly_steps.shape)
# Out:
# (22099, 3)
# (22099, 3)

# %% [markdown]
# Merging two dataframes

# %%
hourly_activity = pd.merge(hourly_calories, hourly_steps, on=['Id', 'ActivityHour'])

hourly_activity.columns = ['Id', 'ActivityHour', 'Calories', 'StepTotal']

# %%
hourly_activity.shape
# Out:
# (22099, 4)

# %%
hourly_activity.head()
# Out:
#            Id           ActivityHour  Calories  StepTotal
# 0  1503960366  4/12/2016 12:00:00 AM        81        373
# 1  1503960366   4/12/2016 1:00:00 AM        61        160
# 2  1503960366   4/12/2016 2:00:00 AM        59        151
# 3  1503960366   4/12/2016 3:00:00 AM        47          0
# 4  1503960366   4/12/2016 4:00:00 AM        48          0

# %%
hourly_activity.tail()
# Out:
#                Id           ActivityHour  Calories  StepTotal
# 22094  8877689391  5/12/2016 10:00:00 AM       126        514
# 22095  8877689391  5/12/2016 11:00:00 AM       192       1407
# 22096  8877689391  5/12/2016 12:00:00 PM       321       3135
# 22097  8877689391   5/12/2016 1:00:00 PM       101        307
# 22098  8877689391   5/12/2016 2:00:00 PM       113        457

# %%
hourly_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  object
#  2   Calories      22099 non-null  int64
#  3   StepTotal     22099 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 690.7+ KB

# %%
hourly_activity['Id'].nunique()
# Out:
# 33

# %% [markdown]
# Data of 33 User in present in the dataset.

# %%
hourly_activity.describe()
# Out:
#                  Id      Calories     StepTotal
# count  2.209900e+04  22099.000000  22099.000000
# mean   4.848235e+09     97.386760    320.166342
# std    2.422500e+09     60.702622    690.384228
# min    1.503960e+09     42.000000      0.000000
# 25%    2.320127e+09     63.000000      0.000000
# 50%    4.445115e+09     83.000000     40.000000
# 75%    6.962181e+09    108.000000    357.000000
# max    8.877689e+09    948.000000  10554.000000

# %%
hourly_activity['ActivityHour'] = pd.to_datetime(hourly_activity['ActivityHour'], format='%m/%d/%Y %I:%M:%S %p')

# %%
hourly_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22099 entries, 0 to 22098
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            22099 non-null  int64
#  1   ActivityHour  22099 non-null  datetime64[ns]
#  2   Calories      22099 non-null  int64
#  3   StepTotal     22099 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 690.7 KB

# %% [markdown]
# Data has been cleaned and proper EDA is done, all the fields have proper data types with no null Values.

# %%
hourly_activity.to_csv('HourlyActivity.csv', index=False)
